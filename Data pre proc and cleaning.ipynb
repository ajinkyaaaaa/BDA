# %% [markdown]
# ## BDA project csv mini project file processing
# ### PE25 Ajinkya Karnik
# immigrants csv's

# %%
import pandas as pd
from glob import glob

# %%
d1 = pd.read_csv('/Users/ajinkyakarnik/Desktop/tri9/BDA/Mini Project/immigrants1.csv')

# %%
d1.head(10)
# Out:
#    Year  District Code District Name  Neighborhood Code  \
# 0  2017              1  Ciutat Vella                  1
# 1  2017              1  Ciutat Vella                  2
# 2  2017              1  Ciutat Vella                  3
# 3  2017              1  Ciutat Vella                  4
# 4  2017              2      Eixample                  5
# 5  2017              2      Eixample                  6
# 6  2017              2      Eixample                  7
# 7  2017              2      Eixample                  8
# 8  2017              2      Eixample                  9
# 9  2017              2      Eixample                 10
#
#                        Neighborhood Name Nationality  Number
# 0                               el Raval       Spain    1109
# 1                         el Barri Gòtic       Spain     482
# 2                         la Barceloneta       Spain     414
# 3  Sant Pere, Santa Caterina i la Ribera       Spain     537
# ...

# %%
d2 = pd.read_csv('/Users/ajinkyakarnik/Desktop/tri9/BDA/Mini Project/immigrants2.csv')

# %%
d2.head(10)
# Out:
#    Year  District Code District Name  Neighborhood Code  \
# 0  2017              1  Ciutat Vella                  1
# 1  2017              1  Ciutat Vella                  2
# 2  2017              1  Ciutat Vella                  3
# 3  2017              1  Ciutat Vella                  4
# 4  2017              2      Eixample                  5
# 5  2017              2      Eixample                  6
# 6  2017              2      Eixample                  7
# 7  2017              2      Eixample                  8
# 8  2017              2      Eixample                  9
# 9  2017              2      Eixample                 10
#
#                        Neighborhood Name  Age  Immigrants  Emigrants
# 0                               el Raval  0-4         154        108
# 1                         el Barri Gòtic  0-4          58         33
# 2                         la Barceloneta  0-4          38         37
# 3  Sant Pere, Santa Caterina i la Ribera  0-4          56         55
# ...

# %%
d3 = pd.read_csv('/Users/ajinkyakarnik/Desktop/tri9/BDA/Mini Project/immigrants3.csv')

# %%
d3.head(5)
# Out:
#    Year  District Code District Name  Neighborhood Code  \
# 0  2017              1  Ciutat Vella                  1
# 1  2017              1  Ciutat Vella                  2
# 2  2017              1  Ciutat Vella                  3
# 3  2017              1  Ciutat Vella                  4
# 4  2017              2      Eixample                  5
#
#                        Neighborhood Name Gender  Immigrants  Emigrants
# 0                               el Raval   Male        3063       1195
# 1                         el Barri Gòtic   Male        1499        427
# 2                         la Barceloneta   Male         910        361
# 3  Sant Pere, Santa Caterina i la Ribera   Male        1438        502
# 4                          el Fort Pienc   Male        1082        495

# %%
d4 = pd.read_csv('/Users/ajinkyakarnik/Desktop/tri9/BDA/Mini Project/immigrants4.csv')

# %%
d4.head(5)
# Out:
#            from                  to  weight
# 0  Ciutat Vella           Andalusia     188
# 1  Ciutat Vella              Aragon      64
# 2  Ciutat Vella      Canary Islands      95
# 3  Ciutat Vella           Cantabria      17
# 4  Ciutat Vella  Castilla-La Mancha      23

# %%
d5 = pd.read_csv('/Users/ajinkyakarnik/Desktop/tri9/BDA/Mini Project/immigrants5.csv')

# %%
d5.head(5)
# Out:
#                from         to  weight
# 0            Abroad  Barcelona   53085
# 1         Andalusia  Barcelona    2416
# 2            Aragon  Barcelona     811
# 3          Asturias  Barcelona     323
# 4  Balearic Islands  Barcelona    1634

# %% [markdown]
# ### Attempted to join the files using pattern matching but data is not the same [3:2]

# %%
data_list = sorted(glob('/Users/ajinkyakarnik/Desktop/tri9/BDA/Mini Project/immigrants*.csv'))
data_list
# Out:
# ['/Users/ajinkyakarnik/Desktop/tri9/BDA/Mini Project/immigrants1.csv',
#  '/Users/ajinkyakarnik/Desktop/tri9/BDA/Mini Project/immigrants2.csv',
#  '/Users/ajinkyakarnik/Desktop/tri9/BDA/Mini Project/immigrants3.csv',
#  '/Users/ajinkyakarnik/Desktop/tri9/BDA/Mini Project/immigrants4.csv',
#  '/Users/ajinkyakarnik/Desktop/tri9/BDA/Mini Project/immigrants5.csv']

# %%
pd.concat((pd.read_csv(file).assign(filename = file)
                      for file in data_list), ignore_index=True)
# Out:
#          Year  District Code District Name  Neighborhood Code  \
# 0      2017.0            1.0  Ciutat Vella                1.0
# 1      2017.0            1.0  Ciutat Vella                2.0
# 2      2017.0            1.0  Ciutat Vella                3.0
# 3      2017.0            1.0  Ciutat Vella                4.0
# 4      2017.0            2.0      Eixample                5.0
# ...       ...            ...           ...                ...
# 41051     NaN            NaN           NaN                NaN
# 41052     NaN            NaN           NaN                NaN
# 41053     NaN            NaN           NaN                NaN
# 41054     NaN            NaN           NaN                NaN
# 41055     NaN            NaN           NaN                NaN
#
#                            Neighborhood Name Nationality  Number  \
# 0                                   el Raval       Spain  1109.0
# 1                             el Barri Gòtic       Spain   482.0
# ...

# %% [markdown]
# ### Joining from-to datasets [d4 and d5]

# %%
immigrants_1 = pd.merge(d4,d5,how="outer")

# %%
immigrants_1
# Out:
#                     from                  to  weight
# 0           Ciutat Vella           Andalusia     188
# 1           Ciutat Vella              Aragon      64
# 2           Ciutat Vella      Canary Islands      95
# 3           Ciutat Vella           Cantabria      17
# 4           Ciutat Vella  Castilla-La Mancha      23
# ..                   ...                 ...     ...
# 435             La Rioja           Barcelona     129
# 436              Melilla           Barcelona      60
# 437              Navarre           Barcelona     246
# 438     Region of Murcia           Barcelona     354
# 439  Valencian Community           Barcelona    2305
#
# [440 rows x 3 columns]

# %% [markdown]
# ##### (Indexing gone wrong)

# %%
d1.reset_index(inplace=True)

# %%
d2.reset_index(inplace=True)

# %% [markdown]
# ### Merging d1 and d2

# %%
immigrants_2 = pd.merge(d1, d2, on=['District Name','Neighborhood Code','Year','District Code'], how='outer', left_index=True, right_index=True)

# %%
immigrants_2
# Out:
#        Neighborhood Code  Year  District Code District Name     Nationality  \
# 0                      1  2017              1  Ciutat Vella           Spain
# 1                      2  2017              1  Ciutat Vella           Spain
# 2                      3  2017              1  Ciutat Vella           Spain
# 3                      4  2017              1  Ciutat Vella           Spain
# 4                      5  2017              2      Eixample           Spain
# ...                  ...   ...            ...           ...             ...
# 35219                 70  2015             10    Sant Martí  No information
# 35220                 71  2015             10    Sant Martí  No information
# 35221                 72  2015             10    Sant Martí  No information
# 35222                 73  2015             10    Sant Martí  No information
# 35223                 99  2015             99     No consta  No information
#
#        Number  Age  Immigrants  Emigrants
# ...

# %%
immigrants_2.head(10)
# Out:
#    Neighborhood Code  Year  District Code District Name Nationality  Number  \
# 0                  1  2017              1  Ciutat Vella       Spain    1109
# 1                  2  2017              1  Ciutat Vella       Spain     482
# 2                  3  2017              1  Ciutat Vella       Spain     414
# 3                  4  2017              1  Ciutat Vella       Spain     537
# 4                  5  2017              2      Eixample       Spain     663
# 5                  6  2017              2      Eixample       Spain    1181
# 6                  7  2017              2      Eixample       Spain    1063
# 7                  8  2017              2      Eixample       Spain    1177
# 8                  9  2017              2      Eixample       Spain    1593
# 9                 10  2017              2      Eixample       Spain     883
#
#    Age  Immigrants  Emigrants
# 0  0-4       154.0      108.0
# 1  0-4        58.0       33.0
# 2  0-4        38.0       37.0
# ...

# %%
immigrants_1.head(10)
# Out:
#            from                   to  weight
# 0  Ciutat Vella            Andalusia     188
# 1  Ciutat Vella               Aragon      64
# 2  Ciutat Vella       Canary Islands      95
# 3  Ciutat Vella            Cantabria      17
# 4  Ciutat Vella   Castilla-La Mancha      23
# 5  Ciutat Vella     Castile and León      39
# 6  Ciutat Vella            Catalonia    2906
# 7  Ciutat Vella                Ceuta       0
# 8  Ciutat Vella  Community of Madrid     259
# 9  Ciutat Vella              Navarre      11

# %%
immigrants_1 = immigrants_1.sort_values(['weight'],ascending=False)

# %%
immigrants_1
# Out:
#                from            to  weight
# 400          Abroad     Barcelona   53085
# 415       Barcelona     Catalonia   35036
# 430       Catalonia     Barcelona   28779
# 311          Abroad      Eixample   11473
# 310          Abroad  Ciutat Vella    8586
# ..              ...           ...     ...
# 7      Ciutat Vella         Ceuta       0
# 67   Horta-Guinardó         Ceuta       0
# 274           Ceuta     Les Corts       0
# 47           Gràcia         Ceuta       0
# 107      Nou Barris         Ceuta       0
#
# [440 rows x 3 columns]

# %%
immigrants_1.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Merging [d1+d2] with d3

# %%
immigrants_3 = pd.merge(immigrants_2, d3, on=['District Name','Neighborhood Code','Year','Immigrants','Emigrants','District Code'], how='outer', left_index=True, right_index=True)

# %% [markdown]
# ### Handling missing values

# %%
immigrants_3 = immigrants_3.sort_values(['Number','Immigrants','Emigrants'],ascending=[0,0,0])
immigrants_3 = immigrants_3.dropna()
immigrants_3
# Out:
#      index  Neighborhood Code  Year  District Code        District Name  \
# 8        8                  9  2017              2             Eixample
# 30      30                 31  2017              6               Gràcia
# 5        5                  6  2017              2             Eixample
# 7        7                  8  2017              2             Eixample
# 25      25                 26  2017              5  Sarrià-Sant Gervasi
# ..     ...                ...   ...            ...                  ...
# 221    221                 99  2017             99            No consta
# 295    295                 99  2017             99            No consta
# 369    369                 99  2017             99            No consta
# 591    591                 99  2017             99            No consta
# 665    665                 99  2017             99            No consta
#
#     Nationality  Number    Age  Immigrants  Emigrants  \
# ...

# %%
immigrants_1.dropna()
immigrants_1.reset_index()
# Out:
#      index                 from                  to  weight
# 0        0         Ciutat Vella           Andalusia     188
# 1        1         Ciutat Vella              Aragon      64
# 2        2         Ciutat Vella      Canary Islands      95
# 3        3         Ciutat Vella           Cantabria      17
# 4        4         Ciutat Vella  Castilla-La Mancha      23
# ..     ...                  ...                 ...     ...
# 435    435             La Rioja           Barcelona     129
# 436    436              Melilla           Barcelona      60
# 437    437              Navarre           Barcelona     246
# 438    438     Region of Murcia           Barcelona     354
# 439    439  Valencian Community           Barcelona    2305
#
# [440 rows x 4 columns]

# %% [markdown]
# #### Checking for null values

# %%
immigrants_1.isnull().values.any()
# Out:
# False

# %%
immigrants_3.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Final datasets

# %%
immigrants_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   from    440 non-null    object
#  1   to      440 non-null    object
#  2   weight  440 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 10.4+ KB

# %%
immigrants_1.head()
# Out:
#           from            to  weight
# 400     Abroad     Barcelona   53085
# 415  Barcelona     Catalonia   35036
# 430  Catalonia     Barcelona   28779
# 311     Abroad      Eixample   11473
# 310     Abroad  Ciutat Vella    8586

# %%
immigrants_1.tail()
# Out:
#                from         to  weight
# 7      Ciutat Vella      Ceuta       0
# 67   Horta-Guinardó      Ceuta       0
# 274           Ceuta  Les Corts       0
# 47           Gràcia      Ceuta       0
# 107      Nou Barris      Ceuta       0

# %%
immigrants_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35224 entries, 0 to 35223
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              35224 non-null  int64
#  1   Neighborhood Code  35224 non-null  int64
#  2   Year               35224 non-null  int64
#  3   District Code      35224 non-null  int64
#  4   District Name      35224 non-null  object
#  5   Nationality        35224 non-null  object
#  6   Number             35224 non-null  int64
#  7   Age                4662 non-null   object
#  8   Immigrants         4662 non-null   float64
#  9   Emigrants          4662 non-null   float64
#  10  Neighborhood Name  730 non-null    object
#  11  Gender             730 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 3.5+ MB

# %%
immigrants_3.head(100)
# Out:
#      index  Neighborhood Code  Year  District Code        District Name  \
# 8        8                  9  2017              2             Eixample
# 30      30                 31  2017              6               Gràcia
# 5        5                  6  2017              2             Eixample
# 7        7                  8  2017              2             Eixample
# 25      25                 26  2017              5  Sarrià-Sant Gervasi
# ..     ...                ...   ...            ...                  ...
# 227    227                  6  2017              2             Eixample
# 91      91                 18  2017              3       Sants-Montjuïc
# 105    105                 32  2017              6               Gràcia
# 38      38                 39  2017              7       Horta-Guinardó
# 669    669                  4  2017              1         Ciutat Vella
#
#     Nationality  Number    Age  Immigrants  Emigrants  \
# ...

# %%
immigrants_3.tail()
# Out:
#      index  Neighborhood Code  Year  District Code District Name Nationality  \
# 221    221                 99  2017             99     No consta       China
# 295    295                 99  2017             99     No consta    Colombia
# 369    369                 99  2017             99     No consta   Venezuela
# 591    591                 99  2017             99     No consta      France
# 665    665                 99  2017             99     No consta        Peru
#
#      Number    Age  Immigrants  Emigrants  \
# 221       0  10-14         0.0        0.0
# 295       0  15-19         0.0        0.0
# 369       0  20-24         0.0        0.0
# 591       0  35-39         0.0        0.0
# 665       0  40-44         0.0        0.0
#
#                          Neighborhood Name  Gender
# 221                         la Barceloneta  Female
# 295  Sant Pere, Santa Caterina i la Ribera    Male
# 369                          el Fort Pienc  Female
# ...

# %% [markdown]
# ### Saving the processed files

# %%
immigrants_1.to_csv('/Users/ajinkyakarnik/Desktop/tri9/BDA/Mini Project/immigrants_processed_1.csv')

# %%
immigrants_3.to_csv('/Users/ajinkyakarnik/Desktop/tri9/BDA/Mini Project/immigrants_processed_2.csv')
